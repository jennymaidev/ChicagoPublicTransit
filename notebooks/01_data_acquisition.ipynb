# %%
import requests
import pandas as pd
import os

DATA_DIR = '../data/raw/'
filename = 'sales_data.csv'
url = 'https://datacatalog.cookcountyil.gov/resource/wvhk-k5uv.csv?$limit=3000000'

# %%
full_filepath = os.path.join(DATA_DIR, filename)

response = requests.get(url, stream=True)

response.raise_for_status()

with open(full_filepath, 'wb') as file:
    for chunk in response.iter_content(chunk_size=8192):
        file.write(chunk)

# %%
df_sales = pd.read_csv(os.path.join(DATA_DIR, 'sales_data.csv'))
df_sales.head()
# Out:
# /var/folders/fk/9chv4jr11ln50p4dhsxntpcw0000gn/T/ipykernel_83581/2852610417.py:1: DtypeWarning: Columns (8,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sales = pd.read_csv(os.path.join(DATA_DIR, 'sales_data.csv'))
#               pin    year  township_code   nbhd class  \
# 0  31012140340000  2000.0             32  32050   278
# 1  14291030261014  2000.0             73  73150   299
# 2  13164060180000  2000.0             71  71101   203
# 3  24233020370000  2014.0             39  39250   100
# 4  19354040600000  2016.0             72  72200   205
#
#                  sale_date  is_mydec_date  sale_price      doc_no deed_type  \
# 0  2000-04-01T00:00:00.000          False    177500.0      317676   Trustee
# 1  2000-02-01T00:00:00.000          False    315000.0      326770  Warranty
# 2  2000-06-01T00:00:00.000          False    192000.0      519440  Warranty
# 3  2014-06-01T00:00:00.000          False       500.0  1427529079     Other
# 4  2016-08-01T00:00:00.000          False         1.0  1625129009  Warranty
#
#   mydec_deed_type seller_name  is_multisale  num_parcels_sale  \
# 0             NaN         NaN         False               1.0
# 1             NaN         NaN         False               1.0
# 2             NaN         NaN         False               1.0
# 3             NaN     US BANK         False               1.0
# 4             NaN         NaN          True               5.0
#
#            buyer_name          sale_type  sale_filter_same_sale_within_365  \
# 0                 NaN  LAND AND BUILDING                             False
# 1                 NaN  LAND AND BUILDING                             False
# 2                 NaN  LAND AND BUILDING                             False
# 3  MY OWN DOMINION LP               LAND                             False
# 4                 NaN  LAND AND BUILDING                              True
#
#    sale_filter_less_than_10k  sale_filter_deed_type    row_id
# 0                      False                  False  96289215
# 1                      False                  False  97142869
# 2                      False                  False  96585660
# 3                       True                  False  96639542
# 4                       True                  False  98154864

# %%
df_sales.isnull().sum()
# Out:
# pin                                       0
# year                                      0
# township_code                             0
# nbhd                                      0
# class                                     0
# sale_date                                 0
# is_mydec_date                             0
# sale_price                                0
# doc_no                                    0
# deed_type                              1159
# mydec_deed_type                     1735359
# seller_name                          170514
# is_multisale                              0
# num_parcels_sale                          0
# buyer_name                           155584
# sale_type                            441803
# sale_filter_same_sale_within_365          0
# sale_filter_less_than_10k                 0
# sale_filter_deed_type                     0
# row_id                                    0
# dtype: int64
